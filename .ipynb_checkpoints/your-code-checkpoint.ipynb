# %% [markdown]
# # Lab: Regression Analysis

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
import pandas as pd
import clipboard as clipboard
import pandas as pd
import numpy as np

# %%
import seaborn as sns                              # plotting library
sns.set(style='white')                             # seaborn style


from sklearn.linear_model import LogisticRegression            # logistic regression model   

from sklearn.preprocessing import StandardScaler               # standarized
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import load_diabetes

from sklearn.ensemble import RandomForestRegressor as RFR

from sklearn.model_selection import train_test_split as tts    # split data into train and test sets

# %%
df_control_c = pd.read_clipboard()
s = df_control_c
s
# Out:
#    StudentID  Age  Tardies
# 0          1   17       10
# 1          2   51        1
# 2          3   27        5
# 3          4   21        9
# 4          5   36        4
# 5          6   48        2
# 6          7   19        9
# 7          8   26        6
# 8          9   54        0
# 9         10   30        3

# %%
sd = s
sd.columns
del sd['StudentID']
sd
# Out:
#    Age  Tardies
# 0   17       10
# 1   51        1
# 2   27        5
# 3   21        9
# 4   36        4
# 5   48        2
# 6   19        9
# 7   26        6
# 8   54        0
# 9   30        3

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})

# %%
plt.scatter(sd.Age, sd.Tardies)
plt.title('Relacion Edad/Tardanza Scatter plot')
plt.xlabel('Age')
plt.ylabel('Tardies')
# Out:
# Text(0, 0.5, 'Tardies')

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %%
# Se ve una clara tendencia a llegar mas repetidamente tarde cuando eres mas joven.

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
cov = sd.cov()
cov
# Out:
#                 Age    Tardies
# Age      187.655556 -45.566667
# Tardies  -45.566667  12.544444

# %%
corr=sd.corr() 

corr
# Out:
#               Age   Tardies
# Age      1.000000 -0.939163
# Tardies -0.939163  1.000000

# %%
fig, ax=plt.subplots(figsize=(10,10))


mask=np.triu(np.ones_like(corr, dtype=bool))           # mask for superior triangular matrix


color_map=sns.diverging_palette(0, 10, as_cmap=True)   # color palette


# correlation heatmap
sns.heatmap(corr,                       # data
            mask=mask,                  # white mask
            cmap='Spectral',             # color                     
            center=0,                   # plot center
            square=True,                # data square representation
            linewidth=0.5,               # linewidth
            cbar_kws={'shrink': 0.5},
            annot=True,
           )
# Out:
# <AxesSubplot:>

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
from scipy import stats
x= sd['Age']
y= sd['Tardies']

slope, intercept, r_value, p_value, std_err= stats.linregress(x, y)

print(slope)
print(intercept)
# Out:
# -0.2428207709159808
# 12.888803363135768

# %% [markdown]
# Plot your regression model on your scatter plot.

# %%
plt.scatter(sd['Age'], sd['Tardies'], label='Age/Tardies')
plt.plot(x, slope*x + intercept, label='regresión')
plt.xlabel('Age')
plt.ylabel('Tardies')
plt.legend();

# %%
from sklearn.linear_model import LinearRegression as LinReg

# %%
Y= sd['Age']
X= sd[['Tardies']]

rl= LinearRegression()
model= rl.fit(X,Y)

print(rl.score(X,Y)*100,'%')
# Out:
# 88.2026555825011 %

# %% [markdown]
# # Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %% [markdown]
# Podemos ver en esta recta que si que hay relacion edad/ veces que llegan tarde

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
vehicles= pd.read_csv('vehicles.csv')

vehicles.head(2)
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General   FJ8c Post Office  1984                  4.2        6.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
print('Relacion de Emision de C02 de Gramos/Milla y Año del coche:', vehicles["CO2 Emission Grams/Mile"].corr(vehicles["Year"]))
      
print('Relacion de Emision de C02 de Gramos/Milla y Cilindrada:', vehicles["CO2 Emission Grams/Mile"].corr(vehicles["Cylinders"]))
      
print('Relacion de Emision de C02 de Gramos/Milla y Barriles de Gasolina:', vehicles["CO2 Emission Grams/Mile"].corr(vehicles["Fuel Barrels/Year"]))
      
print('Relacion de Emision de C02 de Gramos/Milla y Combinado MPG:', vehicles["CO2 Emission Grams/Mile"].corr(vehicles["Combined MPG"]))
      
print('Relacion de Emision de C02 de Gramos/Milla y Coste Gasolina/Año:',vehicles["CO2 Emission Grams/Mile"].corr(vehicles["Fuel Cost/Year"]))
# Out:
# Relacion de Emision de C02 de Gramos/Milla y Año del coche: -0.22229960295054216
# Relacion de Emision de C02 de Gramos/Milla y Cilindrada: 0.752392553729749
# Relacion de Emision de C02 de Gramos/Milla y Barriles de Gasolina: 0.9861886621428733
# Relacion de Emision de C02 de Gramos/Milla y Combinado MPG: -0.9262290389336435
# Relacion de Emision de C02 de Gramos/Milla y Coste Gasolina/Año: 0.9308651512201842

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
from sklearn.linear_model import LinearRegression

# %%
Y= vehicles['CO2 Emission Grams/Mile']
X= vehicles[['Year', 'Cylinders', 'Fuel Barrels/Year', 'Combined MPG', 'Fuel Cost/Year']]

rl= LinearRegression()
model= rl.fit(X,Y)

print(rl.score(X,Y)*100,'%')
# Out:
# 98.08734920269121 %

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
vehicles.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
g = sns.pairplot(vehicles, hue = 'Year');
g.map_lower(sns.kdeplot, levels=4, color=".2")

# %%
sns.heatmap(vehicles.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bonus Challenge: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
error = pd.read_clipboard()
bonus = error
bonus
# Out:
#     X   Y
# 0   1   1
# 1   3   2
# 2   4   4
# 3   6   4
# 4   8   5
# 5   9   7
# 6  11   8
# 7  14  13

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
plt.scatter(bonus.X, bonus.Y)
plt.title('Relacion Gente que invita/Gente que va')
plt.xlabel('Gente que invita')
plt.ylabel('Gente que va')
# Out:
# Text(0, 0.5, 'Gente que va')

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %%
x= bonus['X']
y= bonus['Y']

slope2, intercept2, r_value, p_value, std_err= stats.linregress(x, y)

print(slope2)

print(intercept2)
# Out:
# 0.8484848484848485
# -0.43939393939393945

# %%
plt.scatter(bonus['X'], bonus['Y'], label='Gente')
plt.plot(x, slope2*x + intercept2, label='regresión')
plt.xlabel('Invita')
plt.ylabel('Asiste')
plt.legend();

# %%
Y= bonus['Y']
X= bonus[['X']]

rl= LinearRegression()
model= rl.fit(X,Y)

print(rl.score(X,Y)*100,'%')
# Out:
# 93.16696375519905 %

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
plt.boxplot(bonus)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a9d7963fa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a9d791e2e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a9d7963cd0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2a9d7953a00>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2a9d7953cd0>,
# ...
#  'means': []}

# %%
bonus2 = bonus.drop([7],axis=0)
bonus2
# Out:
#     X  Y
# 0   1  1
# 1   3  2
# 2   4  4
# 3   6  4
# 4   8  5
# 5   9  7
# 6  11  8

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %%
x= bonus2['X']
y= bonus2['Y']

slope3, intercept3, r_value, p_value, std_err= stats.linregress(x, y)

print(slope3)

print(intercept3)
# Out:
# 0.6842105263157895
# 0.32330827067669166

# %%
plt.scatter(bonus2['X'], bonus2['Y'], label='Gente')
plt.plot(x, slope3*x + intercept3, label='regresión')
plt.xlabel('Invita')
plt.ylabel('Asiste')
plt.legend();

# %%
Y= bonus2['Y']
X= bonus2[['X']]

rl= LinearRegression()
model= rl.fit(X,Y)

print(rl.score(X,Y)*100,'%')
# Out:
# 94.33811802232856 %

# %%
# La unica diferencia que encuentro esque la linea de regresion es mas baja y que el score aumenta, es decir aumenta la fiabilidad del estudio.
